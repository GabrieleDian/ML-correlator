# %% [markdown]
# # Introduction to W&B
#
# <!--- @wandbcode{dlai_01} -->
#
# We will add `wandb` to sprite classification model training, so that we can track and visualize important metrics, gain insights into our model's behavior and make informed decisions for model improvements. We will also see how to compare and analyze different experiments, collaborate with team members, and reproduce results effectively.

# %%
import math
from pathlib import Path
from types import SimpleNamespace
from tqdm.auto import tqdm
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam

# %%
import wandb

# %%
from utilities import get_dataloaders
from utilities import show_image

# %% [markdown]
# ### Sprite classification
#
# We will build a simple model to classify sprites. You can see some examples of sprites and corresponding classes in the image below.
#
# <img src="sprite_sample.png" alt="Alt Text" width="700"/>

# %%
INPUT_SIZE = 3 * 16 * 16
OUTPUT_SIZE = 5
HIDDEN_SIZE = 256
NUM_WORKERS = 2
CLASSES = ["hero", "non-hero", "food", "spell", "side-facing"]
DATA_DIR = Path('./data/')
DEVICE = torch.device("cuda" if torch.cuda.is_available()  else "cpu")

def get_model(dropout):
    "Simple MLP with Dropout"
    return nn.Sequential(
        nn.Flatten(),
        nn.Linear(INPUT_SIZE, HIDDEN_SIZE),
        nn.BatchNorm1d(HIDDEN_SIZE),
        nn.ReLU(),
        nn.Dropout(dropout),
        nn.Linear(HIDDEN_SIZE, OUTPUT_SIZE)
    ).to(DEVICE)

# %%
# Let's define a config object to store our hyperparameters
config = SimpleNamespace(
    epochs = 2,
    batch_size = 128,
    lr = 1e-5,
    dropout = 0.5,
    slice_size = 10_000,
    valid_pct = 0.2,
)

# %%
def train_model(config):
    "Train a model with a given config"
    
    wandb.init(
        project="dlai_intro",
        config=config,
    )

    # Get the data
    train_dl, valid_dl = get_dataloaders(DATA_DIR, 
                                         config.batch_size, 
                                         config.slice_size, 
                                         config.valid_pct)
    n_steps_per_epoch = math.ceil(len(train_dl.dataset) / config.batch_size)

    # A simple MLP model
    model = get_model(config.dropout)

    # Make the loss and optimizer
    loss_func = nn.CrossEntropyLoss()
    optimizer = Adam(model.parameters(), lr=config.lr)

    example_ct = 0

    for epoch in tqdm(range(config.epochs), total=config.epochs):
        model.train()

        for step, (images, labels) in enumerate(train_dl):
            
            images, labels = images.to(DEVICE), labels.to(DEVICE)

            outputs = model(images)
            train_loss = loss_func(outputs, labels)
            optimizer.zero_grad()
            train_loss.backward()
            optimizer.step()

            example_ct += len(images)
            metrics = {
                "train/train_loss": train_loss,
                "train/epoch": epoch + 1,
                "train/example_ct": example_ct
            }
            wandb.log(metrics)
            
        # Compute validation metrics, log images on last epoch
        val_loss, accuracy = validate_model(model, valid_dl, loss_func)
        # Compute train and validation metrics
        val_metrics = {
            "val/val_loss": val_loss,
            "val/val_accuracy": accuracy
        }
        wandb.log(val_metrics)
    
    wandb.finish()

# %%
def validate_model(model, valid_dl, loss_func):
    "Compute the performance of the model on the validation dataset"
    model.eval()
    val_loss = 0.0
    correct = 0

    with torch.inference_mode():
        for i, (images, labels) in enumerate(valid_dl):
            images, labels = images.to(DEVICE), labels.to(DEVICE)

            # Forward pass
            outputs = model(images)
            val_loss += loss_func(outputs, labels) * labels.size(0)

            # Compute accuracy and accumulate
            _, predicted = torch.max(outputs.data, 1)
            correct += (predicted == labels).sum().item()
            
    return val_loss / len(valid_dl.dataset), correct / len(valid_dl.dataset)

# %% [markdown]
# ### W&B account
# The next cell will log you into the Weights and Biases site anonymously, that is without a unique login. You can also sign up for a free account if you wish to save your work, but that is not needed to finish the course.

# %%
wandb.login(anonymous="allow")
# Out:
# wandb: Currently logged in as: dian-gabriele (dian-gabriele-desydeutsches-elektronen-synchrotron) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# ### Train model
# Let's train the model with default config and check how it's doing in W&B.

# %%
train_model(config)
# Out:
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>/home/gabriele/Documents/GitHub/ML-correlator/wandb_experiment/L1/wandb/run-20250528_202207-us2r6bz9</code>
# Syncing run <strong><a href='https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro/runs/us2r6bz9?apiKey=ae08a383a928ccd86c87393a659546693003eac1' target="_blank">graceful-sunset-3</a></strong> to <a href='https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro?apiKey=ae08a383a928ccd86c87393a659546693003eac1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro?apiKey=ae08a383a928ccd86c87393a659546693003eac1' target="_blank">https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro?apiKey=ae08a383a928ccd86c87393a659546693003eac1</a>
#  View run at <a href='https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro/runs/us2r6bz9?apiKey=ae08a383a928ccd86c87393a659546693003eac1' target="_blank">https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro/runs/us2r6bz9?apiKey=ae08a383a928ccd86c87393a659546693003eac1</a>
# Do NOT share these links with anyone. They can be used to claim your runs.
# 100%|██████████| 2/2 [00:02<00:00,  1.49s/it]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train/epoch</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁███████████████████</td></tr><tr><td>train/example_ct</td><td>▁▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇█</td></tr><tr><td>train/train_loss</td><td>▇▇█▆▆▇▆▆▇▆▅▆▅▅▅▅▄▆▅▄▅▃▄▃▃▃▄▃▃▂▂▁▂▂▂▂▃▂▂▃</td></tr><tr><td>val/val_accuracy</td><td>▁█</td></tr><tr><td>val/val_loss</td><td>█▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train/epoch</td><td>2</td></tr><tr><td>train/example_ct</td><td>16000</td></tr><tr><td>train/train_loss</td><td>1.31107</td></tr><tr><td>val/val_accuracy</td><td>0.6775</td></tr><tr><td>val/val_loss</td><td>1.12023</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">graceful-sunset-3</strong> at: <a href='https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro/runs/us2r6bz9?apiKey=ae08a383a928ccd86c87393a659546693003eac1' target="_blank">https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro/runs/us2r6bz9?apiKey=ae08a383a928ccd86c87393a659546693003eac1</a><br> View project at: <a href='https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro?apiKey=ae08a383a928ccd86c87393a659546693003eac1' target="_blank">https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro?apiKey=ae08a383a928ccd86c87393a659546693003eac1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250528_202207-us2r6bz9/logs</code>

# %%
# So let's change the learning rate to a 1e-3 
# and see how this affects our results.
config.lr = 1e-4
train_model(config)
# Out:
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>/home/gabriele/Documents/GitHub/ML-correlator/wandb_experiment/L1/wandb/run-20250528_202403-utogq6kc</code>
# Syncing run <strong><a href='https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro/runs/utogq6kc?apiKey=ae08a383a928ccd86c87393a659546693003eac1' target="_blank">vague-leaf-4</a></strong> to <a href='https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro?apiKey=ae08a383a928ccd86c87393a659546693003eac1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro?apiKey=ae08a383a928ccd86c87393a659546693003eac1' target="_blank">https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro?apiKey=ae08a383a928ccd86c87393a659546693003eac1</a>
#  View run at <a href='https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro/runs/utogq6kc?apiKey=ae08a383a928ccd86c87393a659546693003eac1' target="_blank">https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro/runs/utogq6kc?apiKey=ae08a383a928ccd86c87393a659546693003eac1</a>
# Do NOT share these links with anyone. They can be used to claim your runs.
# 100%|██████████| 2/2 [00:03<00:00,  1.50s/it]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train/epoch</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁████████████████████</td></tr><tr><td>train/example_ct</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇██████</td></tr><tr><td>train/train_loss</td><td>██▇▆▅▆▅▅▄▄▄▃▃▃▃▂▂▃▂▂▂▂▂▁▂▁▁▂▂▂▁▂▁▁▂▁▁▁▁▁</td></tr><tr><td>val/val_accuracy</td><td>▁█</td></tr><tr><td>val/val_loss</td><td>█▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train/epoch</td><td>2</td></tr><tr><td>train/example_ct</td><td>16000</td></tr><tr><td>train/train_loss</td><td>0.37365</td></tr><tr><td>val/val_accuracy</td><td>0.9555</td></tr><tr><td>val/val_loss</td><td>0.2926</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">vague-leaf-4</strong> at: <a href='https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro/runs/utogq6kc?apiKey=ae08a383a928ccd86c87393a659546693003eac1' target="_blank">https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro/runs/utogq6kc?apiKey=ae08a383a928ccd86c87393a659546693003eac1</a><br> View project at: <a href='https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro?apiKey=ae08a383a928ccd86c87393a659546693003eac1' target="_blank">https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro?apiKey=ae08a383a928ccd86c87393a659546693003eac1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250528_202403-utogq6kc/logs</code>

# %%
config.lr = 1e-4
train_model(config)
# Out:
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>/home/gabriele/Documents/GitHub/ML-correlator/wandb_experiment/L1/wandb/run-20250528_202501-ju7wp0of</code>
# Syncing run <strong><a href='https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro/runs/ju7wp0of?apiKey=ae08a383a928ccd86c87393a659546693003eac1' target="_blank">blooming-haze-5</a></strong> to <a href='https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro?apiKey=ae08a383a928ccd86c87393a659546693003eac1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro?apiKey=ae08a383a928ccd86c87393a659546693003eac1' target="_blank">https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro?apiKey=ae08a383a928ccd86c87393a659546693003eac1</a>
#  View run at <a href='https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro/runs/ju7wp0of?apiKey=ae08a383a928ccd86c87393a659546693003eac1' target="_blank">https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro/runs/ju7wp0of?apiKey=ae08a383a928ccd86c87393a659546693003eac1</a>
# Do NOT share these links with anyone. They can be used to claim your runs.
# 100%|██████████| 2/2 [00:03<00:00,  1.58s/it]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train/epoch</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁███████████████████████</td></tr><tr><td>train/example_ct</td><td>▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇████</td></tr><tr><td>train/train_loss</td><td>██▇▇▇▆▆▆▅▅▄▄▃▃▃▃▃▃▂▃▃▂▃▃▂▂▂▁▂▁▁▁▂▁▁▁▁▁▁▁</td></tr><tr><td>val/val_accuracy</td><td>▁█</td></tr><tr><td>val/val_loss</td><td>█▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train/epoch</td><td>2</td></tr><tr><td>train/example_ct</td><td>16000</td></tr><tr><td>train/train_loss</td><td>0.29769</td></tr><tr><td>val/val_accuracy</td><td>0.951</td></tr><tr><td>val/val_loss</td><td>0.30902</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">blooming-haze-5</strong> at: <a href='https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro/runs/ju7wp0of?apiKey=ae08a383a928ccd86c87393a659546693003eac1' target="_blank">https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro/runs/ju7wp0of?apiKey=ae08a383a928ccd86c87393a659546693003eac1</a><br> View project at: <a href='https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro?apiKey=ae08a383a928ccd86c87393a659546693003eac1' target="_blank">https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro?apiKey=ae08a383a928ccd86c87393a659546693003eac1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250528_202501-ju7wp0of/logs</code>

# %%
config.dropout = 0.1
config.epochs = 1
train_model(config)
# Out:
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>/home/gabriele/Documents/GitHub/ML-correlator/wandb_experiment/L1/wandb/run-20250528_202506-nf09eg9v</code>
# Syncing run <strong><a href='https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro/runs/nf09eg9v?apiKey=ae08a383a928ccd86c87393a659546693003eac1' target="_blank">sparkling-aardvark-6</a></strong> to <a href='https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro?apiKey=ae08a383a928ccd86c87393a659546693003eac1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro?apiKey=ae08a383a928ccd86c87393a659546693003eac1' target="_blank">https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro?apiKey=ae08a383a928ccd86c87393a659546693003eac1</a>
#  View run at <a href='https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro/runs/nf09eg9v?apiKey=ae08a383a928ccd86c87393a659546693003eac1' target="_blank">https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro/runs/nf09eg9v?apiKey=ae08a383a928ccd86c87393a659546693003eac1</a>
# Do NOT share these links with anyone. They can be used to claim your runs.
# 100%|██████████| 1/1 [00:01<00:00,  1.60s/it]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train/epoch</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/example_ct</td><td>▁▁▁▁▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train/train_loss</td><td>█▇▇▇▆▆▆▅▅▅▄▄▄▄▃▃▃▃▃▃▃▃▃▂▂▂▁▂▂▂▂▂▁▁▁▁▁▂▁▁</td></tr><tr><td>val/val_accuracy</td><td>▁</td></tr><tr><td>val/val_loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train/epoch</td><td>1</td></tr><tr><td>train/example_ct</td><td>8000</td></tr><tr><td>train/train_loss</td><td>0.49868</td></tr><tr><td>val/val_accuracy</td><td>0.9135</td></tr><tr><td>val/val_loss</td><td>0.47604</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">sparkling-aardvark-6</strong> at: <a href='https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro/runs/nf09eg9v?apiKey=ae08a383a928ccd86c87393a659546693003eac1' target="_blank">https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro/runs/nf09eg9v?apiKey=ae08a383a928ccd86c87393a659546693003eac1</a><br> View project at: <a href='https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro?apiKey=ae08a383a928ccd86c87393a659546693003eac1' target="_blank">https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro?apiKey=ae08a383a928ccd86c87393a659546693003eac1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250528_202506-nf09eg9v/logs</code>

# %%
config.lr = 1e-3
train_model(config)
# Out:
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>/home/gabriele/Documents/GitHub/ML-correlator/wandb_experiment/L1/wandb/run-20250528_202509-zqfar7m3</code>
# Syncing run <strong><a href='https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro/runs/zqfar7m3?apiKey=ae08a383a928ccd86c87393a659546693003eac1' target="_blank">sunny-meadow-7</a></strong> to <a href='https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro?apiKey=ae08a383a928ccd86c87393a659546693003eac1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro?apiKey=ae08a383a928ccd86c87393a659546693003eac1' target="_blank">https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro?apiKey=ae08a383a928ccd86c87393a659546693003eac1</a>
#  View run at <a href='https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro/runs/zqfar7m3?apiKey=ae08a383a928ccd86c87393a659546693003eac1' target="_blank">https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro/runs/zqfar7m3?apiKey=ae08a383a928ccd86c87393a659546693003eac1</a>
# Do NOT share these links with anyone. They can be used to claim your runs.
# 100%|██████████| 1/1 [00:01<00:00,  1.49s/it]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train/epoch</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/example_ct</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇███</td></tr><tr><td>train/train_loss</td><td>█▅▄▄▃▃▂▂▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val/val_accuracy</td><td>▁</td></tr><tr><td>val/val_loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train/epoch</td><td>1</td></tr><tr><td>train/example_ct</td><td>8000</td></tr><tr><td>train/train_loss</td><td>0.04581</td></tr><tr><td>val/val_accuracy</td><td>0.9905</td></tr><tr><td>val/val_loss</td><td>0.05947</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">sunny-meadow-7</strong> at: <a href='https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro/runs/zqfar7m3?apiKey=ae08a383a928ccd86c87393a659546693003eac1' target="_blank">https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro/runs/zqfar7m3?apiKey=ae08a383a928ccd86c87393a659546693003eac1</a><br> View project at: <a href='https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro?apiKey=ae08a383a928ccd86c87393a659546693003eac1' target="_blank">https://wandb.ai/dian-gabriele-desydeutsches-elektronen-synchrotron/dlai_intro?apiKey=ae08a383a928ccd86c87393a659546693003eac1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250528_202509-zqfar7m3/logs</code>

# %%
wandb.finish()
