# %%
import torch
import numpy as np
from types import SimpleNamespace
import argparse
from pathlib import Path

# Import the simple dataset creator
from graphbuilder_simple import create_simple_dataset, quick_dataset_stats
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       5 from pathlib import Path
#       7 # Import the simple dataset creator
# ----> 8 from graphbuilder_simple import create_simple_dataset, quick_dataset_stats
#
# File ~/Documents/ML-correlator/GNN/graphbuilder_simple.py:8
#       6 import torch
#       7 import numpy as np
# ----> 8 from torch_geometric.data import Data
#       9 from sklearn.preprocessing import StandardScaler
#      10 from load_features import load_saved_features, load_graph_structure
#
# ModuleNotFoundError: No module named 'torch_geometric'

# %%
    # Create dataset with pre-computed features
    print("\nLoading pre-computed features...")
    # Pass base_dir to dataset creation
    dataset, scaler = create_simple_dataset(
        loop_order=7,
        selected_features= ['degree', 'betweenness', 'clustering','laplacian_eigenvalues_normalized'],
        normalize=True,
        data_dir='../Graph_Edge_Data'
    )
# Out:
# Loading pre-computed features...
# Loading features: ['degree', 'betweenness', 'clustering', 'laplacian_eigenvalues_normalized']
# Loaded degree: shape (164, 11)
# Loaded betweenness: shape (164, 11)
# Loaded clustering: shape (164, 11)
# Loaded laplacian_eigenvalues_normalized: shape (164, 11)
# Loading graph structures...
# Building dataset...
# Created dataset with 164 graphs
# Feature dimension: 4
# Normalizing features...

# %%
dataset[0].x
# Out:
# tensor([[-0.7333, -1.0203,  1.6017, -2.1366],
#         [-0.7333, -1.0203,  1.6017, -1.0376],
#         [ 0.6002, -0.1952,  0.1214, -0.7401],
#         [ 0.6002, -0.1952,  0.1214, -0.7266],
#         [ 0.6002, -0.0147,  0.1214,  0.3337],
#         [ 0.6002, -0.0147,  0.1214,  0.4273],
#         [ 0.6002, -0.0921,  0.1214,  0.4746],
#         [ 0.6002, -0.0921,  0.1214,  0.7200],
#         [ 0.6002, -0.0921,  0.1214,  0.7401],
#         [ 0.6002, -0.0921,  0.1214,  0.9548],
#         [ 1.9337,  1.5582, -0.7668,  0.9903]])
