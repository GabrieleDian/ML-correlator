# %%
from src.sp_encoding import create_spm_model
import pandas as pd

# %%
# ---- load data and write text corpus ----
df0 = pd.read_csv(
    "/Users/rezadoobary/Documents/ML-correlator/Transformers/data/g6encodings/den_graph_data_7_encodings.csv",
    index_col=0
)

# ---- load data and write text corpus ----
df1 = pd.read_csv(
    "/Users/rezadoobary/Documents/ML-correlator/Transformers/data/g6encodings/den_graph_data_8_encodings.csv",
    index_col=0
)
df = pd.concat([df0,df1])
temp_dir, sp_model = create_spm_model(df, vocab_size = 325)
# Out:
# [info] Temp folder: /Users/rezadoobary/Documents/ML-correlator/Transformers/.temp/768719
# [info] Wrote corpus to: /Users/rezadoobary/Documents/ML-correlator/Transformers/.temp/768719/encodings.txt
# [done] Model files:
#   /Users/rezadoobary/Documents/ML-correlator/Transformers/.temp/768719/mymodel.model
#   /Users/rezadoobary/Documents/ML-correlator/Transformers/.temp/768719/mymodel.vocab
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: /Users/rezadoobary/Documents/ML-correlator/Transformers/.temp/768719/encodings.txt
#   input_format:
#   model_prefix: /Users/rezadoobary/Documents/ML-correlator/Transformers/.temp/768719/mymodel
#   model_type: BPE
#   vocab_size: 325
#   self_test_sample_size: 0
#   character_coverage: 1
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
# ...

# %%
# Out:
#       COEFFICIENTS     ENCODINGS
# 0                1   JO\KkvaqPt_
# 1                1   J@macvpTsg_
# 2                1   JDcqownEtN?
# 3                1   Jr?LCs[mkn?
# 4                1   JbHObsK^LV?
# ...            ...           ...
# 1427             0  KEFbCgKGgvHV
# 1428             0  KKpK`DaaSHz]
# 1429             0  KHbWbGK``_rr
# 1430             0  KHbWbGK``_rr
# 1431             0  KEFbCgKGgv]^
#
# [1596 rows x 2 columns]
