# %%
import pandas as pd

# %%
pd.read_csv("/Users/rezadoobary/Documents/MLcorr_docs/loop11/motifs_eig_centrality_/loop11_motifs_eig_centrality_shap_full.csv")
# Out:
#                              feature  importance  mean_signed_shap
# 0                 Spectral_lap_eig_1    5.121813         -2.963805
# 1   Motif_induced_connected_per_4set    1.471274         -0.200764
# 2       Motif_triangle_edge_frac_ge2    0.859031         -0.377269
# 3                 Spectral_lap_eig_2    0.855132          0.258815
# 4         Centrality_betweenness_std    0.732301          0.440846
# ..                               ...         ...               ...
# 93     Motif_induced5_g_17_5_per_Cn5    0.000000          0.000000
# 94     Motif_induced5_g_13_5_per_Cn5    0.000000          0.000000
# 95     Motif_induced5_g_20_5_per_Cn5    0.000000          0.000000
# 96             Motif_induced5_g_17_5    0.000000          0.000000
# 97       Motif_induced_g_6_4_per_Cn4    0.000000          0.000000
#
# [98 rows x 3 columns]

# %%
pd.read_csv("/Users/rezadoobary/Documents/MLcorr_docs/loop11/motifs_eig_centrality_/loop11_motifs_eig_centrality_shap_sample.csv")
# Out:
#       Motif_4_cliques  Motif_4_cliques_per_Cn4  Motif_4_cycles  \
# 0                 0.0                      0.0       -0.214910
# 1                 0.0                      0.0       -0.245690
# 2                 0.0                      0.0       -0.209382
# 3                 0.0                      0.0       -0.317388
# 4                 0.0                      0.0        0.646576
# ...               ...                      ...             ...
# 9995              0.0                      0.0       -0.586676
# 9996              0.0                      0.0       -0.003899
# 9997              0.0                      0.0       -0.138912
# 9998              0.0                      0.0       -0.513253
# 9999              0.0                      0.0       -0.334823
#
#       Motif_4_cycles_per_Cn4  Motif_induced_connected_per_4set  \
# 0                  -0.015424                          0.140853
# 1                  -0.063005                          1.133147
# ...
