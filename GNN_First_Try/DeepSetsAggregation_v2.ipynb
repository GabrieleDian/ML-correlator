# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import  global_mean_pool
#from graph_builder import GraphBuilder  # <-- External builder
import pandas as pd
from torch_geometric.loader import DataLoader
from torch_geometric.nn import GCNConv, global_add_pool, GraphNorm, DeepSetsAggregation
from sklearn.model_selection import train_test_split
import ast
from torch_geometric.utils import degree

# %%
from GraphBuilder_single_edge import GraphBuilder
from save_model_results import save_model_architecture, append_evaluation_results, evaluate_model

# %% [markdown]
# ## Model architecture

# %%
class SimpleGNN(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, dropout):
        super().__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.norm1 = GraphNorm(hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.norm2 = GraphNorm(hidden_channels)
        
        self.conv3 = GCNConv(hidden_channels, hidden_channels)
        self.norm3 = GraphNorm(hidden_channels)

        self.pool = DeepSetsAggregation(
            local_nn=nn.Sequential(
                nn.Linear(hidden_channels, hidden_channels),
                nn.ReLU()
            ),
            global_nn=nn.Sequential(
                nn.Linear(hidden_channels, hidden_channels),
                nn.ReLU()
            )
        )
        
        self.lin1 = nn.Linear(hidden_channels, hidden_channels)
        self.lin2 = nn.Linear(hidden_channels, 2)
        self.dropout = nn.Dropout(dropout)

    def forward(self, data):
        x, edge_index, batch = data.x, data.edge_index, data.batch

        x = F.relu(self.norm1(self.conv1(x, edge_index)))
        x = self.dropout(x)

        x = F.relu(self.norm2(self.conv2(x, edge_index)))
        x = self.dropout(x)

        x = F.relu(self.norm3(self.conv3(x, edge_index)))
        x = self.dropout(x)

        x = self.pool(x, batch)

        x = self.lin1(x)
        
        return self.lin2(x)

# %%
# Create the model object.
model = SimpleGNN(in_channels=4, hidden_channels=32,dropout=0.2)

# %%
criterion = nn.CrossEntropyLoss()
learning_rate = 0.001
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate, weight_decay=5e-4)

# %%
# Generate text file with model architecture
model_results_path = save_model_architecture(model)
model_results_path
#model_results_path = "results/model_3.txt"
# Out:
# 'results/model_4.txt'

# %% [markdown]
# ## 7-10 loop

# %% [markdown]
# ### Data preparation

# %%
loop=9

# %%
# Reset model parameteters
for layer in model.children():
   if hasattr(layer, 'reset_parameters'):
       layer.reset_parameters()

# %% [markdown]
# First we read the edges and coefficients of the csv files and save them in lists.

# %%
# Create the edge and y lists from the csv files\
edges=[]
y=[]
for i in range(loop,loop+1):
    filename = f'../Graph_Edge_Data/den_graph_data_{loop}.csv'
    df = pd.read_csv(filename)
    edges += df['EDGES'].tolist()
    y += df['COEFFICIENTS'].tolist()
edges = [ast.literal_eval(e) for e in edges]

# %%
# Import the function to add eigenvector features
from torch_geometric.transforms import AddLaplacianEigenvectorPE
eigen_vec= AddLaplacianEigenvectorPE(k=3,attr_name=None)

# %% [markdown]
# We need to now translate the edges into dataset forms for training and testing.

# %%
# Define the data object through GraphBuilder, then add the eigenvector features
data=[GraphBuilder(solid_edges=x,coeff=y0).build() for x,y0 in zip(edges,y)]
data = [eigen_vec(d) for d in data]

# %%
# Split train and test data
train_data, test_data = train_test_split(data, test_size=0.2, random_state=43)

# %%
# Load the data into DataLoader
train_loader = DataLoader(train_data, batch_size=20, shuffle=True)
test_loader = DataLoader(test_data, batch_size=20, shuffle=False)

# %% [markdown]
# ### Model training

# %% [markdown]
# We are interested in graph classification of 0 and 1. We add two graph convolutional layers, making sure that the message passing is extended to two neighbours, and then add graph pooling to average over the whole graph.

# %%
def train_model(model, train_loader, test_loader, optimizer, criterion, device, n_epochs=70):
    accuracy_list = []
    loss_list = []
    patience_counter = 0
    patience = 3
    model.to(device)

    for epoch in range(n_epochs):
        model.train()
        total_loss = 0

        for batch in train_loader:
            batch = batch.to(device)
            optimizer.zero_grad()

            out = model(batch)             # out = model(batch) handles batch.x, batch.edge_index, etc.
            loss = criterion(out, batch.coeff) # Use batch.y (or batch.coeff if that's what your dataset uses)

            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        loss_list.append(total_loss)

        # Validation
        model.eval()
        correct = 0
        total = 0

        with torch.no_grad():
            for batch in test_loader:
                batch = batch.to(device)
                out = model(batch)
                _, predicted = torch.max(out, 1)
                correct += (predicted == batch.coeff).sum().item()
                total += batch.num_graphs  # graph-level classification

        accuracy = correct / total
        accuracy_list.append(accuracy)

        print(f"Epoch {epoch+1}: Loss={total_loss:.2f}, Accuracy={accuracy:.2f}")

        if epoch>50: 
            if loss_list[epoch-10]-loss_list[epoch] < 0.1:
                patience_counter += 1
                if patience_counter >= patience:
                    print("Early stopping") 
                    break

# %%
train_model(model,train_loader,test_loader,optimizer,device='cpu',criterion=criterion)
# Out:
# Epoch 1: Loss=320.64, Accuracy=0.76
# Epoch 2: Loss=300.84, Accuracy=0.75
# Epoch 3: Loss=294.80, Accuracy=0.76
# Epoch 4: Loss=289.03, Accuracy=0.76
# Epoch 5: Loss=287.42, Accuracy=0.77
# Epoch 6: Loss=283.09, Accuracy=0.77
# Epoch 7: Loss=280.42, Accuracy=0.77
# Epoch 8: Loss=276.32, Accuracy=0.77
# Epoch 9: Loss=273.92, Accuracy=0.78
# Epoch 10: Loss=273.99, Accuracy=0.78
# Epoch 11: Loss=274.69, Accuracy=0.78
# Epoch 12: Loss=269.97, Accuracy=0.79
# Epoch 13: Loss=269.02, Accuracy=0.78
# Epoch 14: Loss=269.59, Accuracy=0.78
# Epoch 15: Loss=267.17, Accuracy=0.78
# Epoch 16: Loss=265.12, Accuracy=0.78
# Epoch 17: Loss=264.07, Accuracy=0.79
# Epoch 18: Loss=265.31, Accuracy=0.78
# Epoch 19: Loss=262.65, Accuracy=0.78
# Epoch 20: Loss=261.40, Accuracy=0.79
# Epoch 21: Loss=260.48, Accuracy=0.80
# Epoch 22: Loss=262.29, Accuracy=0.79
# Epoch 23: Loss=258.36, Accuracy=0.79
# Epoch 24: Loss=261.66, Accuracy=0.79
# Epoch 25: Loss=260.28, Accuracy=0.78
# Epoch 26: Loss=258.76, Accuracy=0.78
# Epoch 27: Loss=261.34, Accuracy=0.79
# Epoch 28: Loss=254.59, Accuracy=0.79
# Epoch 29: Loss=256.17, Accuracy=0.80
# Epoch 30: Loss=259.60, Accuracy=0.80
# Epoch 31: Loss=256.89, Accuracy=0.79
# Epoch 32: Loss=257.55, Accuracy=0.78
# Epoch 33: Loss=259.18, Accuracy=0.80
# Epoch 34: Loss=255.26, Accuracy=0.79
# Epoch 35: Loss=256.63, Accuracy=0.79
# Epoch 36: Loss=252.61, Accuracy=0.79
# Epoch 37: Loss=256.25, Accuracy=0.79
# Epoch 38: Loss=255.50, Accuracy=0.80
# Epoch 39: Loss=254.86, Accuracy=0.79
# Epoch 40: Loss=254.62, Accuracy=0.80
# Epoch 41: Loss=250.63, Accuracy=0.79
# Epoch 42: Loss=252.85, Accuracy=0.80
# Epoch 43: Loss=255.16, Accuracy=0.80
# Epoch 44: Loss=254.25, Accuracy=0.80
# Epoch 45: Loss=251.98, Accuracy=0.80
# Epoch 46: Loss=253.69, Accuracy=0.80
# Epoch 47: Loss=249.69, Accuracy=0.80
# Epoch 48: Loss=254.27, Accuracy=0.80
# Epoch 49: Loss=250.73, Accuracy=0.80
# Epoch 50: Loss=252.60, Accuracy=0.79
# Epoch 51: Loss=254.17, Accuracy=0.79
# Epoch 52: Loss=252.27, Accuracy=0.79
# Epoch 53: Loss=253.50, Accuracy=0.79
# Epoch 54: Loss=253.33, Accuracy=0.80
# Epoch 55: Loss=254.35, Accuracy=0.79
# Epoch 56: Loss=250.76, Accuracy=0.79
# Epoch 57: Loss=253.82, Accuracy=0.79
# Epoch 58: Loss=249.71, Accuracy=0.79
# Epoch 59: Loss=252.24, Accuracy=0.80
# Early stopping

# %% [markdown]
# ### Model evaluation

# %% [markdown]
# We evaluate the model on test set in terms of Accuracy, Precision, Recall and F1 score. Then we save the results in a txt file. Then we also print the same metrics for the training set.

# %%
evaluation =evaluate_model(model, test_loader, device='cpu')

# %%
append_evaluation_results(model_results_path, evaluation, loop = loop )

# %%
#Save results on training set
evaluation =evaluate_model(model, train_loader, device='cpu', set_type = "train")
append_evaluation_results(model_results_path, evaluation, loop = loop)
