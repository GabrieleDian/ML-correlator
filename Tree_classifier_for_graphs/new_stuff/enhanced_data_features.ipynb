# %%
import pandas as pd
import numpy as np

# %%
x0 = pd.read_csv("/Users/rezadoobary/Documents/MLCorrelator2/ML-correlator/Tree_classifier_for_graphs/new_stuff/features/den_graphs/5loopfeats_enhanced.csv")
x1 = pd.read_csv("/Users/rezadoobary/Documents/MLCorrelator2/ML-correlator/Tree_classifier_for_graphs/new_stuff/features/den_graphs2/5loops.csv")
df = pd.concat([x0,x1], axis = 1)
df = df.loc[:, ~df.columns.duplicated()]

df.to_csv("/Users/rezadoobary/Documents/MLCorrelator2/ML-correlator/Tree_classifier_for_graphs/new_stuff/features/merged/5loops.csv")

# %%
x0 = pd.read_csv("/Users/rezadoobary/Documents/MLCorrelator2/ML-correlator/Tree_classifier_for_graphs/new_stuff/features/den_graphs/6loopfeats_enhanced.csv")
x1 = pd.read_csv("/Users/rezadoobary/Documents/MLCorrelator2/ML-correlator/Tree_classifier_for_graphs/new_stuff/features/den_graphs2/6loops.csv")
df = pd.concat([x0,x1], axis = 1)
df = df.loc[:, ~df.columns.duplicated()]

df.to_csv("/Users/rezadoobary/Documents/MLCorrelator2/ML-correlator/Tree_classifier_for_graphs/new_stuff/features/merged/6loops.csv")

# %%
x0 = pd.read_csv("/Users/rezadoobary/Documents/MLCorrelator2/ML-correlator/Tree_classifier_for_graphs/new_stuff/features/den_graphs/7loopfeats_enhanced.csv")
x1 = pd.read_csv("/Users/rezadoobary/Documents/MLCorrelator2/ML-correlator/Tree_classifier_for_graphs/new_stuff/features/den_graphs2/7loops.csv")
df = pd.concat([x0,x1], axis = 1)
df = df.loc[:, ~df.columns.duplicated()]

df.to_csv("/Users/rezadoobary/Documents/MLCorrelator2/ML-correlator/Tree_classifier_for_graphs/new_stuff/features/merged/7loops.csv")

# %%
x0 = pd.read_csv("/Users/rezadoobary/Documents/MLCorrelator2/ML-correlator/Tree_classifier_for_graphs/new_stuff/features/den_graphs/8loopfeats_enhanced.csv")
x1 = pd.read_csv("/Users/rezadoobary/Documents/MLCorrelator2/ML-correlator/Tree_classifier_for_graphs/new_stuff/features/den_graphs2/8loops.csv")
df = pd.concat([x0,x1], axis = 1)
df = df.loc[:, ~df.columns.duplicated()]

df.to_csv("/Users/rezadoobary/Documents/MLCorrelator2/ML-correlator/Tree_classifier_for_graphs/new_stuff/features/merged/8loops.csv")

# %%
x0 = pd.read_csv("/Users/rezadoobary/Documents/MLCorrelator2/ML-correlator/Tree_classifier_for_graphs/new_stuff/features/den_graphs/9loopfeats_enhanced.csv")
x1 = pd.read_csv("/Users/rezadoobary/Documents/MLCorrelator2/ML-correlator/Tree_classifier_for_graphs/new_stuff/features/den_graphs2/9loops.csv")
df = pd.concat([x0,x1], axis = 1)
df = df.loc[:, ~df.columns.duplicated()]

df.to_csv("/Users/rezadoobary/Documents/MLCorrelator2/ML-correlator/Tree_classifier_for_graphs/new_stuff/features/merged/9loops.csv")

# %%
from tqdm import tqdm

# %%
import glob
ordered_files = np.sort(np.array(glob.glob("/Users/rezadoobary/Documents/MLCorrelator2/ML-correlator/Tree_classifier_for_graphs/new_stuff/features/den_graphs2/10loops/*.csv")))
pds = []
for o in tqdm(ordered_files):
    x = pd.read_csv(o)
    pds.append(x)
x1 = pd.concat(pds,axis = 0)
x1 = x1.reset_index()
x0 = pd.read_csv("/Users/rezadoobary/Documents/MLCorrelator2/ML-correlator/Tree_classifier_for_graphs/new_stuff/features/den_graphs/10loopfeats_enhanced.csv")
df = pd.concat([x0,x1], axis = 1)
df = df.loc[:, ~df.columns.duplicated()]

df.to_csv("/Users/rezadoobary/Documents/MLCorrelator2/ML-correlator/Tree_classifier_for_graphs/new_stuff/features/merged/10loops.csv")
# Out:
# 100%|██████████| 31/31 [00:00<00:00, 31.49it/s]
