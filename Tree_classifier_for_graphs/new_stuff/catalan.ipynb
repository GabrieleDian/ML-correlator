# %%
# catalan numbers

# %%
import pandas as pd

dfs = []
for i in [5,6,7,8,9,10,11]:
    dfs.append(pd.read_csv(f"/Users/rezadoobary/Documents/MLCorrelator2/ML-correlator/Graph_Edge_Data/graph_data_{i}.csv"))

# %%
for i in range(0,7):
    val = dfs[i]['COEFFICIENTS'].astype(str).map(eval)
    print(i+5, int(val.max()),int(val.min()))
# Out:
# 5 1 -1
# 6 2 -1
# 7 2 -1
# 8 2 -5
# 9 2 -5
# 10 14 -5
# 11 14 -5

# %%
dfs[0].shape
# Out:
# (7, 3)

# %%
dfs[-2].shape
# Out:
# (900145, 3)

# %%
dfs[1]['COEFFICIENTS'].astype(str).map(eval).max(),dfs[1]['COEFFICIENTS'].astype(str).map(eval).min()
# Out:
# 2

# %%
dfs[2]['COEFFICIENTS'].astype(str).map(eval).max()
# Out:
# 2

# %%
dfs[3]['COEFFICIENTS'].astype(str).map(eval).max()
# Out:
# 2.0

# %%
dfs[4]['COEFFICIENTS'].astype(str).map(eval).max()
# Out:
# 2.0

# %%
dfs[]['COEFFICIENTS'].astype(str).map(eval).max()
# Out:
# 14.0

# %%
df = pd.read_csv("/Users/rezadoobary/Documents/MLCorrelator2/ML-correlator/Tree_classifier_for_graphs/new_stuff/features/fgraphs/7loops.csv")

# %%
df
# Out:
#      Basic_num_nodes_DEN  Basic_num_edges_DEN  Basic_min_degree_DEN  \
# 0                     11                   27                     4
# 1                     11                   27                     4
# 2                     11                   27                     4
# 3                     11                   27                     4
# 4                     11                   27                     4
# ..                   ...                  ...                   ...
# 215                   11                   25                     4
# 216                   11                   26                     4
# 217                   11                   24                     4
# 218                   11                   25                     4
# 219                   11                   23                     4
#
#      Basic_max_degree_DEN  Basic_avg_degree_DEN  Basic_degree_std_DEN  \
# 0                       6              4.909091              0.514259
# ...

# %%
pd.read_csv("/Users/rezadoobary/Documents/MLCorrelator2/ML-correlator/Tree_classifier_for_graphs/new_stuff/features/fgraphs/6loops.csv").shape
# Out:
# (36, 394)

# %%
core = pd.read_csv("/Users/rezadoobary/Documents/MLCorrelator2/ML-correlator/Graph_Edge_Data/graph_data_5.csv")

# %%
df
# Out:
#    Basic_num_nodes_DEN  Basic_num_edges_DEN  Basic_min_degree_DEN  \
# 0                    9                   21                     4
# 1                    9                   20                     4
# 2                    9                   21                     4
# 3                    9                   21                     4
# 4                    9                   19                     4
# 5                    9                   21                     4
# 6                    9                   18                     4
#
#    Basic_max_degree_DEN  Basic_avg_degree_DEN  Basic_degree_std_DEN  \
# 0                     5              4.666667              0.471405
# 1                     5              4.444444              0.496904
# 2                     6              4.666667              0.666667
# 3                     6              4.666667              0.816497
# 4                     5              4.222222              0.415740
# ...

# %%
core
# Out:
#    COEFFICIENTS                                          DEN_EDGES  \
# 0             1  [(1, 5), (1, 6), (1, 8), (1, 9), (2, 4), (2, 6...
# 1            -1  [(1, 3), (1, 4), (1, 8), (1, 9), (2, 3), (2, 4...
# 2             1  [(1, 4), (1, 6), (1, 8), (1, 9), (2, 3), (2, 5...
# 3             1  [(1, 2), (1, 6), (1, 7), (1, 9), (2, 6), (2, 7...
# 4            -1  [(1, 2), (1, 3), (1, 4), (1, 9), (2, 3), (2, 4...
# 5             1  [(1, 6), (1, 7), (1, 8), (1, 9), (2, 3), (2, 5...
# 6             1  [(1, 6), (1, 7), (1, 8), (1, 9), (2, 4), (2, 5...
#
#                   NUM_EDGES
# 0  [(4, 6), (5, 8), (7, 9)]
# 1          [(6, 8), (7, 9)]
# 2  [(5, 9), (6, 9), (7, 8)]
# 3  [(6, 7), (8, 9), (8, 9)]
# 4                  [(8, 9)]
# 5  [(8, 9), (8, 9), (8, 9)]
# 6                        []
