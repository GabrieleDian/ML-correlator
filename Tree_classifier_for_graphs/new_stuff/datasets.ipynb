# %%
import pandas as pd

df = pd.read_csv("/Users/rezadoobary/Documents/MLCorrelator2/ML-correlator/Tree_classifier_for_graphs/new_stuff/features/den_graphs/5loopfeats_enhanced.csv")
print(df.shape)

[x for x in df.columns if 'motif' in x.lower()]
# Out:
# (7, 178)
# ['Motif_triangles',
#  'Motif_wedges',
#  'Motif_4_cycles',
#  'Motif_4_cliques',
#  'Motif_triangle_edge_incidence_mean',
#  'Motif_triangle_edge_incidence_std',
#  'Motif_square_clustering_proxy',
#  'Motif_triangle_edge_incidence_median',
#  'Motif_triangle_edge_incidence_q90',
#  'Motif_triangle_edge_frac_zero',
#  'Motif_triangle_edge_frac_ge2',
#  'Motif_induced_K1_3',
#  'Motif_induced_P4',
#  'Motif_induced_C4',
#  'Motif_induced_TailedTriangle',
#  'Motif_induced_Diamond',
#  'Motif_induced_K4',
#  'Motif_induced_connected_per_4set',
#  'Motif_triangles_per_Cn3',
#  'Motif_4_cycles_per_Cn4',
#  'Motif_4_cliques_per_Cn4',
#  'Motif_wedges_per_max',
#  'Motif_induced_K1_3_per_Cn4',
#  'Motif_induced_P4_per_Cn4',
#  'Motif_induced_C4_per_Cn4',
#  'Motif_induced_TailedTriangle_per_Cn4',
#  'Motif_induced_Diamond_per_Cn4',
#  'Motif_induced_K4_per_Cn4']

# %% [markdown]
# These features are coming from :
#
# /Users/rezadoobary/Documents/MLCorrelator2/ML-correlator/Tree_classifier_for_graphs/mixed_loops/mixed_loops_tab_features_v2.ipynb
#
# no 5 moitifs
#
# slimmer - feature set

# %%
df = pd.read_csv("/Users/rezadoobary/Documents/MLCorrelator2/ML-correlator/Tree_classifier_for_graphs/new_stuff/features/den_graphs2/5loops.csv")
print(df.shape)
[x for x in df.columns if 'motif' in x.lower()]
# Out:
# (7, 128)
# ['Motif_triangles',
#  'Motif_wedges',
#  'Motif_4_cycles',
#  'Motif_4_cliques',
#  'Motif_triangle_edge_incidence_mean',
#  'Motif_triangle_edge_incidence_std',
#  'Motif_square_clustering_proxy',
#  'Motif_triangle_edge_incidence_median',
#  'Motif_triangle_edge_incidence_q90',
#  'Motif_triangle_edge_frac_zero',
#  'Motif_triangle_edge_frac_ge2',
#  'Motif_5_cycles',
#  'Motif_5_cliques',
#  'Motif_induced_K1_3',
#  'Motif_induced_P4',
#  'Motif_induced_C4',
#  'Motif_induced_TailedTriangle',
#  'Motif_induced_Diamond',
#  'Motif_induced_K4',
#  'Motif_induced_connected_per_4set',
#  'Motif_induced5_G5_00',
#  'Motif_induced5_G5_01',
#  'Motif_induced5_G5_02',
#  'Motif_induced5_G5_03',
#  'Motif_induced5_G5_04',
#  'Motif_induced5_G5_05',
#  'Motif_induced5_G5_06',
#  'Motif_induced5_G5_07',
#  'Motif_induced5_G5_08',
#  'Motif_induced5_G5_09',
#  'Motif_induced5_G5_10',
#  'Motif_induced5_G5_11',
#  'Motif_induced5_G5_12',
#  'Motif_induced5_G5_13',
# ...

# %% [markdown]
# has 5 motifs

# %%
df = pd.read_csv("/Users/rezadoobary/Documents/MLCorrelator2/ML-correlator/Tree_classifier_for_graphs/new_stuff/features/fgraphs/5loops.csv")
print(df.shape)
[x for x in df.columns if 'motif' in x.lower()]
# Out:
# (7, 382)
# ['Motif_triangles_DEN',
#  'Motif_wedges_DEN',
#  'Motif_4_cycles_DEN',
#  'Motif_4_cliques_DEN',
#  'Motif_triangle_edge_incidence_mean_DEN',
#  'Motif_triangle_edge_incidence_std_DEN',
#  'Motif_square_clustering_proxy_DEN',
#  'Motif_triangle_edge_incidence_median_DEN',
#  'Motif_triangle_edge_incidence_q90_DEN',
#  'Motif_triangle_edge_frac_zero_DEN',
#  'Motif_triangle_edge_frac_ge2_DEN',
#  'Motif_5_cycles_DEN',
#  'Motif_5_cliques_DEN',
#  'Motif_induced_K1_3_DEN',
#  'Motif_induced_P4_DEN',
#  'Motif_induced_C4_DEN',
#  'Motif_induced_TailedTriangle_DEN',
#  'Motif_induced_Diamond_DEN',
#  'Motif_induced_K4_DEN',
#  'Motif_induced_connected_per_4set_DEN',
#  'Motif_induced5_G5_00_DEN',
#  'Motif_induced5_G5_01_DEN',
#  'Motif_induced5_G5_02_DEN',
#  'Motif_induced5_G5_03_DEN',
#  'Motif_induced5_G5_04_DEN',
#  'Motif_induced5_G5_05_DEN',
#  'Motif_induced5_G5_06_DEN',
#  'Motif_induced5_G5_07_DEN',
#  'Motif_induced5_G5_08_DEN',
#  'Motif_induced5_G5_09_DEN',
# ...
