# %%
import numpy as np

# %%
# Open the file located in Graph_Edge_data/features_loop_7 called 'laplacian_eigenvectors.npy'
file_path = '../Graph_Edge_data/features_loop_7/laplacian_eigenvectors.npy'
eigenvectors = np.load('../Graph_Edge_data/features_loop_7/laplacian_eigenvectors.npy')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Open the file located in Graph_Edge_data/features_loop_7 called 'laplacian_eigenvectors.npy'
#       2 file_path = '../Graph_Edge_data/features_loop_7/laplacian_eigenvectors.npy'
# ----> 3 eigenvectors = np.load('../Graph_Edge_data/features_loop_7/laplacian_eigenvectors.npy')
#
# File ~/Documents/GitHub/Human-Learning/.venv/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py:451, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     449     own_fid = False
#     450 else:
# --> 451     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     452     own_fid = True
#     454 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Graph_Edge_data/features_loop_7/laplacian_eigenvectors.npy'
